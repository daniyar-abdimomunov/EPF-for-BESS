# %% [markdown]
# # Example Notebook 02:
# ## Data Preparation

# %%
# %load_ext autoreload
# %autoreload 2

from src import TimeXerDataModule
import config

# %%
# Prepare data.
data = TimeXerDataModule(**config.DATA_DE_CONFIG | config.BATTERY_CONFIG)

# %%
# Validate dataloader.
test_loader = data.test_dataloader()

# %%
batch = next(iter(test_loader))

# %%
batch_x, batch_y, batch_x_mark, batch_y_mark, batch_sol, batch_obj = batch

# %%
batch_x.shape, batch_y.shape, batch_x_mark.shape, batch_y_mark.shape, batch_sol.shape, batch_obj.shape
